# %% [markdown]
# <a href="https://colab.research.google.com/github/Sameer1980/Devlp_reposit/blob/main/test1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install pyspark

# %%
from pyspark import SparkContext,SparkConf

# %%
# Initializing Spark

# %%
conf=SparkConf().setAppName("testApp1").setMaster("loca[2]")
